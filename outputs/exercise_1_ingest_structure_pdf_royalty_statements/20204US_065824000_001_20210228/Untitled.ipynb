# %%
import pandas as pd

# %%
df = pd.read_csv('music_royalties.csv')

# %%
df
# Out:
#                  income_type  statement_id distribution_period  \
# 0                 Mechanical          2117         17/04-17/06
# 1                 Mechanical          2118         17/07-17/09
# 2                 Mechanical          2119         17/07-17/09
# 3                 Mechanical          6636         17/10-17/12
# 4                 Mechanical          6639         17/10-17/12
# ...                      ...           ...                 ...
# 30730  Streaming Performance         23862         20/04-20/06
# 30731          Digital Synch         23983         20/04-20/06
# 30732   Streaming Mechanical         23986         19/01-20/09
# 30733   Streaming Mechanical         23988         20/07-20/09
# 30734   Streaming Mechanical         23989         20/07-20/09
#
#          income_provider exploitation_country  exploitation_source  \
# 0      AMCOS New Zealand          New Zealand       NZ AUDIO/VIDEO
# 1                  AMCOS            Australia  AUDIO/VIDEO PROGRAM
# ...
